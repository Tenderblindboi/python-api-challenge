# %%
# Import and set all required dependencies
import gmaps
import os
import json
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests


# Import Google API key
from config import g_key

# %%
# load city list from weatherpy challenge
# Print df results
file = pd.read_csv("../WeatherPy/city_list.csv")
file.dropna()
file.head()
# Out:
#    City ID           City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0     Bredasdorp          93      ZA  1584987834        77 -34.53
# 1        1  Yermakovskoye         100      RU  1584987834        84  53.28
# 2        2   Punta Arenas         100      CL  1584987803        77 -53.15
# 3        3    Senftenberg           0      DE  1584987835        40  51.52
# 4        4          Rocha           0      UY  1584987835        38 -34.48
#
#      Lng  Max Temp  Wind Speed
# 0  20.04     64.99        2.24
# 1  92.40     15.55        8.77
# 2 -70.92     62.01       20.80
# 3  14.02     37.40        6.93
# 4 -54.33     83.05        9.15

# %%
# Set Gmaps with the G-key
gmaps.configure(api_key=g_key)

# Store 'Lat' and 'Lng' from DF into lists
locations = file[["Lat", "Lng"]]
humidity = file["Humidity"].astype(float)

# %%
# Heatmap
fig = gmaps.figure(center = [0,0] ,zoom_level = 2)

# Add heat layer over map 
heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                               dissipating=False, max_intensity=100,
                               point_radius = 4)
fig.add_layer(heat_layer)
#Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# configuration of perfect conditions (my perfect conditions)
temp_file=file.loc[(file['Max Temp']>=60)&(file['Max Temp']<=90)]
wind_file=temp_file.loc[(temp_file['Wind Speed']<=5)]
ideal_weather=wind_file.loc[(wind_file['Cloudiness']==0)]
ideal_weather.head()
# Out:
#      City ID      City  Cloudiness Country        Date  Humidity    Lat  \
# 92        92   Kyaikto           0      MM  1584987841        60  17.30
# 99        99     Umluj           0      SA  1584987842        27  25.02
# 157      157  Bac Lieu           0      VN  1584987576        87   9.29
# 160      160    Castro           0      BR  1584987847        34 -24.79
# 193      193   Kalawit           0      PH  1584987849        87   8.07
#
#         Lng  Max Temp  Wind Speed
# 92    97.02     70.99        2.91
# 99    37.27     70.99        3.42
# 157  105.72     75.49        4.03
# 160  -50.01     77.29        3.13
# 193  122.52     74.23        4.81

# %%
# create hotel file
hotel_df = ideal_weather.reset_index(drop=True)
hotel_df["Hotel Name"] = ""

# parameters
params = {
    "radius": 50000,
    "types": "hotel",
    "keyword": "hotels",
    "key": g_key
}

# Use the lat/lng we recovered to identify hotels
for index, row in hotel_df.iterrows():
    
    # latitudes and longitudes from df
    lat = row["Lat"]
    lng = row["Lng"]
    
    # change location each iteration while leaving original params in place
    params["location"] = f"{lat},{lng}"
    
    # Use the search term: "Hotels" and our lat/lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    # make request and print url
    hotel_name = requests.get(base_url, params=params)
    
    # convert to json
    hotel_name = hotel_name.json()
    print(json.dumps(hotel_name, indent=4, sort_keys=True))
    
    # Since some data may be missing we incorporate a try-except to skip any that are missing a data point.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotel_name["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
hotel_df
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CrQCIgEAAOjLn7EwbK8bkb46mQCr2DIScjlGMQa-H1kthyTXOhL-iogtj2s8qegWKW8EaRZ3oEhXyuYHI7M_nHIcQGHoPuxHgJiBnTwYV73EwZkM8FlvPoBb-QF3X2p8VzGkk9qEytoD2vll7WSviILYEbJX21Gmqybzi02DWbJabEa9FeAj9THg2fuNNugfNU66zEKRUCBvzu6cQmlFDXpy-VRlqZN6u-Hrl0JwHjCYLA2mc6sdftdXKMYMiTyLwrqOO7Z6slFydQgBSt47qYGXH9XyDZqi0ZEDZjHlBoMsV2YRmvfFSY1cu8TR2VPxDfkX1Czcjl6Wmj89Q8Ri69wh5sMRXrGViXHce_RoTs51yVPghLAW-etL1kO4HZTMnaQ-iEAppQ53CYraAHXXSANHK96JjE4SEHNCn9Fsm85mrjDKVPtbx1EaFJWuB6bxkmVpsqSJoxcSukG6Z2fh",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4046817,
#                     "lng": 97.0760258
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.40585722989272,
#                         "lng": 97.07723522989272
#                     },
#                     "southwest": {
#                         "lat": 17.40315757010728,
#                         "lng": 97.07453557010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "61b44550d3ab684637ba39513acf534b23f9df16",
#             "name": "The Merit Resort",
#             "photos": [
#                 {
#                     "height": 2160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117533351404231749505\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATcf9Nqv3A_-JLkSOa8YUA_TbUrXkIU5WQvA_-S0McK6Mrl86zY2nBv9kxjwFHg7EpTfu9ATxyKUCFXb541GnrHccWxoMhTYDKOGjfD4YDQUr6Ht4LqVzJBESVCbmDmzNEhAyr8NiSOZrcLgRcYXMt5CUGhTmZS_n_r8yAx7fpJtDjxiuvv3_uA",
#                     "width": 2880
#                 }
#             ],
#             "place_id": "ChIJo3NM7fKnwzARV-8DpZp3_J0",
#             "plus_code": {
#                 "compound_code": "C33G+VC Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9VC33G+VC"
#             },
#             "rating": 4.8,
#             "reference": "ChIJo3NM7fKnwzARV-8DpZp3_J0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 12,
#             "vicinity": "Golden Rock Mountain Rd, Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4816206,
#                     "lng": 97.0982157
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.48313597989272,
#                         "lng": 97.09977257989273
#                     },
#                     "southwest": {
#                         "lat": 17.48043632010728,
#                         "lng": 97.09707292010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "098fa30c3f61e9c33b74a43ebc068e92bec76bf4",
#             "name": "Kyaiktiyo Pagoda",
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111734954765805439958\">Richard Sealy</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnL-3KgPHsY0Z54hu7SVI9lm8_lF4VBbbDHG-ybOGJGv_uMbOa3ggt6ylHFtB9WWunFfkJHmZOgKwWIHtqi0KdHSnf1S0YqBAYUiDivmzuoAlDAwCMNniXYQUQTlmY_jhEhD1SJd1OW6BvA4wkUp85SQ8GhSg-AZgegKTnsw9o_WacUlGMJaL-g",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJ4Sr7SncKwzAR-pZe4Rjgu-M",
#             "plus_code": {
#                 "compound_code": "F3JX+J7 Ka Dai Dutt, Myanmar (Burma)",
#                 "global_code": "7M9VF3JX+J7"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ4Sr7SncKwzAR-pZe4Rjgu-M",
#             "scope": "GOOGLE",
#             "types": [
#                 "tourist_attraction",
#                 "place_of_worship",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2830,
#             "vicinity": "Myanmar (Burma)"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3714923,
#                     "lng": 96.9946315
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.37278747989272,
#                         "lng": 96.99659355
#                     },
#                     "southwest": {
#                         "lat": 17.37008782010728,
#                         "lng": 96.98874534999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "125df5cd730a29005a1c20a904eec89ac234c309",
#             "name": "Sane Let Tin Lake View Hotel",
#             "photos": [
#                 {
#                     "height": 900,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102830083051192622027\">\u1001\u102d\u102f\u1004\u1039 \u1019\u102c</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAbxDz02zMhxn3bZKqmtMDV3sgVb30omn3LtEv66d44uhRwQN1cSAI172qC0pOgnPrH8ZTMlqYiB6fa3UnkpPr0lWCedczMMppqjtyxIiSrikHErxsLW2ygX9sTQAI9HFuEhDCMTIfDo1SJjT_cdKZdUr5GhQjKnyjsSm8lK_KF6quq-OIa1KIfg",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJvzoc7f-lwzARCAtAGzRXWIE",
#             "plus_code": {
#                 "compound_code": "9XCV+HV Boyagyi, Myanmar (Burma)",
#                 "global_code": "7M9R9XCV+HV"
#             },
#             "rating": 5,
#             "reference": "ChIJvzoc7f-lwzARCAtAGzRXWIE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Kyaikto"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4765653,
#                     "lng": 97.101855
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.47790207989272,
#                         "lng": 97.10313517989273
#                     },
#                     "southwest": {
#                         "lat": 17.47520242010728,
#                         "lng": 97.10043552010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "821378d195ecd95922d1bcc2858fdf481ebe4554",
#             "name": "Mountain Top Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101093823470402567203\">Aung Pyae Phyo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIItSDWEh5JbWXaR3jQ7WwSooA67mR7a_OB1yhMWWDf--kAH5F9rgl7NmYnuILI_CAHBQdq3ILEIe9pMWuB33mG4FBU5L1uYKzGhNod0XHvTfVXQQoqBRwdjsN-L6O65UEhC_RvCgS-O04qT952kW1m5aGhSyQq05uXua2NxW_xi5F7xfPANJxg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJtQfWJXIKwzARKiFqxO5wFqE",
#             "plus_code": {
#                 "compound_code": "F4G2+JP Pee Ti Village, Myanmar (Burma)",
#                 "global_code": "7M9VF4G2+JP"
#             },
#             "rating": 4,
#             "reference": "ChIJtQfWJXIKwzARKiFqxO5wFqE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 459,
#             "vicinity": "Foreigner's Registration Office, Near Kyaiktiyo Pagoda, Adjacent to the, \u1000\u103b\u102d\u102f\u1000\u103a\u1011\u102d\u102f"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4075528,
#                     "lng": 97.0738093
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.40884837989272,
#                         "lng": 97.07499762989274
#                     },
#                     "southwest": {
#                         "lat": 17.40614872010728,
#                         "lng": 97.07229797010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "9bcd0389457df1feefd7a966d28330301a6b8735",
#             "name": "The Eternity Resort Hotel",
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106694658307484238757\">\ucd5c\ub9b0</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAWTRc7UKju3UutFuLHnRH9DANOzqNuOR6aADR9LZNSMz0HwugK0iYUuKu5yjiRMUIuQNUC-DNfECAAljrGf5C3mvLnBIgf4_EeZYqiEgcJy1jyq1uhggeOzQb49BzRkVqEhCgYmVrCzhoPXwLpPZPwI_KGhRyv7LpPBw8QCOwHLowCPUg_iskLA",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJQ0NcfnOnwzARUAfPVvEv1nM",
#             "plus_code": {
#                 "compound_code": "C35F+2G Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9VC35F+2G"
#             },
#             "rating": 4.2,
#             "reference": "ChIJQ0NcfnOnwzARUAfPVvEv1nM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 136,
#             "vicinity": "Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4112339,
#                     "lng": 97.07326739999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.41256107989272,
#                         "lng": 97.0743673798927
#                     },
#                     "southwest": {
#                         "lat": 17.40986142010728,
#                         "lng": 97.07166772010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "00211c4519243a0768eff8e2a42216a3c718d74b",
#             "name": "Pepper Garden Resort",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 640,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114745162831679866081\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAq6dteP-brXHczihpcY-wa4FmCKLX6rtVJd0QBg6gVTsgnD2RW-ZiGGVXZkBGxpt7NcOrEqrEfA9n_zmSwlbq6_7T2xMYzSnzeOjxZjUx2ZhF0JGCreoPejB3q4sBvtr5EhC34ZEFr5CRWnQc43Qxotv-GhSChxk_CV4kYzYFqBMLvSKE0Cx23A",
#                     "width": 960
#                 }
#             ],
#             "place_id": "ChIJwakz-XWnwzAR0-knKjfLJ5s",
#             "plus_code": {
#                 "compound_code": "C36F+F8 Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9VC36F+F8"
#             },
#             "rating": 3.9,
#             "reference": "ChIJwakz-XWnwzAR0-knKjfLJ5s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 54,
#             "vicinity": "Golden Rock Mountain Rd, Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.5907588,
#                     "lng": 96.5781927
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.59152972989272,
#                         "lng": 96.57948550000003
#                     },
#                     "southwest": {
#                         "lat": 17.58883007010728,
#                         "lng": 96.5743143
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1048f4032ecdfa772ddfcdaeaacb68b043d47c5e",
#             "name": "Moe Yun Gyi Wetlands Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1012,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118021358253276699225\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAd__xu_0SUHcUgbxQMi1xND20aRCLH3uWEWjPCuFdwGpW-5gLWaI1L8G1KEz6yPTpNCwIrFpKTCvePx5vwvUPZqPLdi-L0Jb3-Wu-vm-Vejvo8v2OIUzXPrzmkW8cxd2BEhDiC9EGyrX35imz3egPFSPwGhSbsqhiwRDIPBJKHaMh_LT41HwbSA",
#                     "width": 1600
#                 }
#             ],
#             "place_id": "ChIJU2fzeBjowzARtSkhc_B40io",
#             "plus_code": {
#                 "compound_code": "HHRH+87 Bo Te Su, Pyinbongyi, Myanmar (Burma)",
#                 "global_code": "7M9RHHRH+87"
#             },
#             "rating": 3.9,
#             "reference": "ChIJU2fzeBjowzARtSkhc_B40io",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 29,
#             "vicinity": "Pyin Bone Gyi Village, Yangon - Mandalay Hwy, \u1015\u1032\u1001\u1030\u1038\u1019\u103c\u102d\u102f\u1037"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4703505,
#                     "lng": 97.0990089
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.47171497989272,
#                         "lng": 97.10035467989273
#                     },
#                     "southwest": {
#                         "lat": 17.46901532010728,
#                         "lng": 97.0976550201073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "150598dafe2f99391799bb40e01ca2925ff6bf35",
#             "name": "Golden Rock Hotel Myanmar",
#             "photos": [
#                 {
#                     "height": 584,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112645142343840876758\">i 500</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw1nmrbKKDSMJdq7qFdEnWZqRjBSPxYm0zaWgJ1y-muMFKTGME-49W5kxuIOFiMqr9VNFtwx6oVtLwmCGd3esal9mdUFh1kCEGmF9OGfk-yC_RQRyRUwJmkD9AVCraq2KEhB9784xrudM5aV43saTqpldGhTbeK2j_aQ-m2FmskaGjn5Ss1rVkw",
#                     "width": 864
#                 }
#             ],
#             "place_id": "ChIJD63lOMwLwzARE-mF_v9gBRY",
#             "plus_code": {
#                 "compound_code": "F3CX+4J Pee Ti Village, Myanmar (Burma)",
#                 "global_code": "7M9VF3CX+4J"
#             },
#             "rating": 3.7,
#             "reference": "ChIJD63lOMwLwzARE-mF_v9gBRY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 34,
#             "vicinity": "Near Kyaiktiyo Pagoda, Kyaikto Township"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4111813,
#                     "lng": 97.07326409999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.41250887989272,
#                         "lng": 97.07436832989272
#                     },
#                     "southwest": {
#                         "lat": 17.40980922010727,
#                         "lng": 97.07166867010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "aaecdf720a1e47d7a45a0f47c5d2aa0905cb4e9f",
#             "name": "Pepper Garden Resort - Kyaikto",
#             "photos": [
#                 {
#                     "height": 2592,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108692615221838314979\">win maung</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjeRmqN0QYFFz4F6fxn4xJWIkUg44OJw9NRhPZVKgHXhgc8hqg-Q8sRNWaBodIsRK25GAGeh9bYeSRJEXvYK5YlKVdEQKdqpDiD0dd4fBiM-PoH4DvPy_84stc7SvcsOGEhBHAxgGHfrEPGhrQHAtmyoqGhRssk-jGwHhHgbcU7QStamRaYBmtw",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJYxWW73KnwzAR2XVQxZ9EUIk",
#             "plus_code": {
#                 "compound_code": "C36F+F8 Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9VC36F+F8"
#             },
#             "rating": 4.5,
#             "reference": "ChIJYxWW73KnwzAR2XVQxZ9EUIk",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "Myanmar (Burma)"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.5901606,
#                     "lng": 96.5795449
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.59123062989272,
#                         "lng": 96.58151380000004
#                     },
#                     "southwest": {
#                         "lat": 17.58853097010728,
#                         "lng": 96.5736382
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "62fe7204b3307185efb3220178c2263e6fab4f4f",
#             "name": "Moe Yun Gyi Wetland Resort",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 3456,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107545238407262004296\">\u798f\u7530\u6e05\u5cf0</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnnVuj50wNI65FvFHLxs_0mQHD4hNODeJESHw2XCT19w4fCfQaUqy8B9VrkMgJIPgE0KBhA1K2GsqwqX4bZZAAMNPtKmicY7mZbvPVITRqx6SedWc7LjL_MVOlcfWddV7EhCIt3MXLCiQf9Pzdcs2BgokGhSlkFdaiKOjqvnUsGZFWVHuyTDknw",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJCRFyE3bowzARhrj_OPi0aH8",
#             "plus_code": {
#                 "compound_code": "HHRH+3R Bo Te Su, Pyinbongyi, Myanmar (Burma)",
#                 "global_code": "7M9RHHRH+3R"
#             },
#             "price_level": 2,
#             "rating": 3.7,
#             "reference": "ChIJCRFyE3bowzARhrj_OPi0aH8",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 64,
#             "vicinity": "\u1015\u1032\u1001\u1030\u1038 (\u1015\u103a\u1025\u1039\u1015\u102f\u1036\u1080\u1000\u102e\u1038, Pegu"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3996922,
#                     "lng": 97.0779017
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.40113357989273,
#                         "lng": 97.07931832989273
#                     },
#                     "southwest": {
#                         "lat": 17.39843392010728,
#                         "lng": 97.0766186701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "cd5ff29128d4895bb750caee3a840baf25228ea4",
#             "name": "Bawga Theiddhi Hotel, Kyeikhto",
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115393712914343486905\">Shine Htet</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAGdY6BPBUYGkjL_odP9H09UzObOvZiXaSFIHmCxRXUDtCqPnrhDuJdnBas6OqqFkY0YI_S21pKgFA4rnjGcr9M6od8urKQsh7aBqdBL-yc7P7UQhc7vPp7Z9wm0B6u9QsEhAKLdBcufaerwZr7sw-YJtbGhRhv9aWp2_OcfkkeBiqB9XekIGqWQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJObQDwZ2nwzAR7-BGEJ5r7Qg",
#             "plus_code": {
#                 "compound_code": "93XH+V5 Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9V93XH+V5"
#             },
#             "rating": 3.8,
#             "reference": "ChIJObQDwZ2nwzAR7-BGEJ5r7Qg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 139,
#             "vicinity": "Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3959713,
#                     "lng": 97.0738373
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.39721647989272,
#                         "lng": 97.07527462989272
#                     },
#                     "southwest": {
#                         "lat": 17.39451682010727,
#                         "lng": 97.07257497010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "677fe5e6c4ee96821555062fc7298df2e904aa95",
#             "name": "Golden Sunrise",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113024153912067356611\">Manuel Parra Quijada</a>"
#                     ],
#                     "photo_reference": "CmRaAAAArpzvmlxbFUcyaYufVXPuSRuMjXiQlsTep3ErvTiZBL1B_MkzkdL5klisvOEed8OfUnA-xlAstDabYV2GZ6PDhJ6wXcfAcTNv-TB5vOLc1WbmpmQMh6ahf8gnX836egPlEhA_6nPS8mDgBkN5-WdsEuOoGhQCv24cYx_d-YPQ8a7noLZIc5FxAg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJWXfEK5-nwzARukan0K9b4Hw",
#             "plus_code": {
#                 "compound_code": "93WF+9G Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9V93WF+9G"
#             },
#             "rating": 4,
#             "reference": "ChIJWXfEK5-nwzARukan0K9b4Hw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 156,
#             "vicinity": "Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4773395,
#                     "lng": 97.1011685
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.47874347989272,
#                         "lng": 97.10258122989272
#                     },
#                     "southwest": {
#                         "lat": 17.47604382010728,
#                         "lng": 97.09988157010729
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "36b90db5ed9aef38ee99f48179d7b89111a75e06",
#             "name": "Kyaik Hto Hotel \u1000\u103b\u102d\u102f\u1000\u103a\u1011\u102d\u102f \u101f\u102d\u102f\u1010\u101a\u103a",
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107057514203388562783\">Soe Thiha</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAUIqSTGZX--3UbRPDfb_xDep9LzvB4Aw2t0QmTSOmp08jGncDmWv32GuPw4U2RX_6nviY3RK0jFbK-9PNK6RW-4qcfSIPmxr2XJIo54Xr8Oa0Un1rXZRA6RwOusxO04fhEhAph3FB4K6WCAmfdQ3jFWnhGhS9_mxWR96LfPlogfpZ-1fRLRQQPg",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ-31WdnEKwzARak-1cJAsEOg",
#             "plus_code": {
#                 "compound_code": "F4G2+WF Pee Ti Village, Myanmar (Burma)",
#                 "global_code": "7M9VF4G2+WF"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ-31WdnEKwzARak-1cJAsEOg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "Kyike Hto Mountain, Kyaikto"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.400867,
#                     "lng": 97.07994219999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.40212302989272,
#                         "lng": 97.08136617989271
#                     },
#                     "southwest": {
#                         "lat": 17.39942337010728,
#                         "lng": 97.07866652010726
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "bdf0340055a5614812f4b9958d4ab2d234cab8f8",
#             "name": "Pann Myo Thu Inn",
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100314082245786529757\">Hall Man</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAjdc05WihaPPLWId-wEn3mWmtIsT1JLvunENubYtfhIeGGskfow6R3dGAZ5GEzJrgagYWcxWGoGusENNsQiCQtj8AGA7e8Kh-JiQmpYseZJjt8lFIVHCOgfwfoiGMjbyIEhDvEqW5qOAz92ypvORbvYtdGhRhB5fF0XCGyfoAQpjHHCsAkqDUBg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJaXIBmJ2nwzARrhcxsNgEnh8",
#             "plus_code": {
#                 "compound_code": "C32H+8X Kin Pun Sakhan, Myanmar (Burma)",
#                 "global_code": "7M9VC32H+8X"
#             },
#             "rating": 3.1,
#             "reference": "ChIJaXIBmJ2nwzARrhcxsNgEnh8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 42,
#             "vicinity": "Kin Pun Sakhan, Kyaikhto, Kyaiktiyo Pagoda Rd, Kin Pun Sakhan"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3284193,
#                     "lng": 97.02888999999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.32973267989273,
#                         "lng": 97.03032372989271
#                     },
#                     "southwest": {
#                         "lat": 17.32703302010728,
#                         "lng": 97.02762407010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "92a4c04467a72f1b97a05adf9a2b2670ab58dcc6",
#             "name": "Thuwunna Bomi Mountain View Hotel & Resort",
#             "photos": [
#                 {
#                     "height": 1155,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111248301497549889781\">kaungmyat oo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6CmC0NY2SlqHfR5HY5rhHScVkyon6GrkqpoZznSe6PrEylBfPSf513Rk7lcpwcCBIvdgKjtQUXUl39_mNuY8Tzor-3roVcqn21DDEe60sQ7AG2mfKz5MJc3ZImBMUD55EhDW9ReaV-jpwGfYbLyaMLKUGhT6xt6i-RWrGAnLLaER4S8QZiNcSQ",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJ_5USuiqpwzARgnqUHL55xgs",
#             "plus_code": {
#                 "compound_code": "82HH+9H Kyaikto, Myanmar (Burma)",
#                 "global_code": "7M9V82HH+9H"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ_5USuiqpwzARgnqUHL55xgs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 132,
#             "vicinity": "Kyaikto"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 16.9175483,
#                     "lng": 97.3637356
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.91892587989271,
#                         "lng": 97.36505987989273
#                     },
#                     "southwest": {
#                         "lat": 16.91622622010727,
#                         "lng": 97.36236022010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8555faa5e0fa1a0ed06e1bc246e61b36cf60a304",
#             "name": "Thuwanna Bumi Hotel",
#             "photos": [
#                 {
#                     "height": 2400,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108242546675420519826\">Khinmaywin Wan</a>"
#                     ],
#                     "photo_reference": "CmRZAAAAX8ogg2Tk8vAhrWaNj14IE5y8r3DhB8r2fLOIVxuUYXUWZ_fNr88QjDb6lfQUkUxL5RRDat3MTRqrBPdnHJ_kiDNC3VlF_jmR7iBhi8IlBHTqQqHz7vSUKqU2OVtIKxjNEhC3nxdFcwC8nDBUDaczHlQgGhTUbtnSO-vSgbYHo4bz-IquQAKsxg",
#                     "width": 1350
#                 }
#             ],
#             "place_id": "ChIJH44d9tzpwjARrxtVUKc9szM",
#             "plus_code": {
#                 "compound_code": "W997+2F Thaton, Myanmar (Burma)",
#                 "global_code": "7M8VW997+2F"
#             },
#             "rating": 3.9,
#             "reference": "ChIJH44d9tzpwjARrxtVUKc9szM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "Unnamed Road, Thaton"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3282966,
#                     "lng": 97.0288906
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.32961792989272,
#                         "lng": 97.03029647989273
#                     },
#                     "southwest": {
#                         "lat": 17.32691827010728,
#                         "lng": 97.02759682010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6dd95e148fd6593011e8794e7ba34ea5a62315e6",
#             "name": "Suvarnabhumi Mountain View Hotel & Resort",
#             "photos": [
#                 {
#                     "height": 2976,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110599426401842814075\">The Theory Man</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhlgM3UbncuULCLV20C3OKfBrcF6t57EYnrFBCEZw16nSNT6dh-hZI_XRhYUW9qG74JwtAChh8ipMwoheEkTWEkqIQ9BIBy9dawXXpGFSJVAzBUd5K3B6n-cYqW1liAgxEhAOFunUpbauyT22W2pGT4-7GhRudwZ8n-Wnj3OKcOehDRL8_i6_cQ",
#                     "width": 3968
#                 }
#             ],
#             "place_id": "ChIJMezwcuqowzARGa5Cc35TCXA",
#             "plus_code": {
#                 "compound_code": "82HH+8H Kyaikto, Myanmar (Burma)",
#                 "global_code": "7M9V82HH+8H"
#             },
#             "rating": 3.9,
#             "reference": "ChIJMezwcuqowzARGa5Cc35TCXA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 53,
#             "vicinity": "Myanmar (Burma)"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.3686726,
#                     "lng": 96.9933836
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.36963362989272,
#                         "lng": 96.99421385
#                     },
#                     "southwest": {
#                         "lat": 17.36693397010728,
#                         "lng": 96.99089285
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "8825993fffb19be250325b15f2ef6343a4052b61",
#             "name": "\u1005\u102d\u1019\u103a\u1038\u101c\u1032\u1037\u1010\u1004\u103a",
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105046638507835226720\">Raymond Htoo</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdPUguzjlKjcymHpzO82EDGSriHeA8ylVG6YlQjv2aVroM0BE3iXl0FpVrs7AZQhF_ZSJI41pbNGK_3GVDuc1X_omQ5ztBlC5PZb9VPwlEjayNiGqIA-bXRMUAFLGlcQFEhBteEYgvizVtykHwQobbEDDGhSsIQX6_hIE4sNyMH1LQINzQxqkrQ",
#                     "width": 5504
#                 }
#             ],
#             "place_id": "ChIJRVZewPGlwzARTTj8znKjti0",
#             "plus_code": {
#                 "compound_code": "9X9V+F9 Boyagyi, Myanmar (Burma)",
#                 "global_code": "7M9R9X9V+F9"
#             },
#             "rating": 3.7,
#             "reference": "ChIJRVZewPGlwzARTTj8znKjti0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1024,
#             "vicinity": "8"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 16.9191047,
#                     "lng": 97.3682165
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 16.92058047989272,
#                         "lng": 97.36951752989273
#                     },
#                     "southwest": {
#                         "lat": 16.91788082010727,
#                         "lng": 97.3668178701073
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "eec3d1c017d5f7859084506775177d2165d9eeb7",
#             "name": "Thuwunnabumi Hotel, Thaton",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 786,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118440905658670978420\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAi-LzxRB8xAvaMZSvG2dxrktsGbX24NbUvzoFwChse9WuvyxE-ngfWLSE-FC1RyikxZH8IOWBe1f-LYiIOCB7DFYOTXmY4gBbG8i-gkzizkEZQvwNqCPOLqgwpDYx_J-JEhB5D-UunWqvoL0VCkuZRDDVGhRNTaH0SEVYRf9q6qB3QHJvHzOECw",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJqXjAWrTpwjARt3WDFxfhVho",
#             "plus_code": {
#                 "compound_code": "W999+J7 Thaton, Myanmar (Burma)",
#                 "global_code": "7M8VW999+J7"
#             },
#             "rating": 3.7,
#             "reference": "ChIJqXjAWrTpwjARt3WDFxfhVho",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 22,
#             "vicinity": "Corner of Myathapaik Pagoda & District Hospital Road, Thaton"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 17.4825892,
#                     "lng": 97.0976665
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 17.48393722989272,
#                         "lng": 97.09912392989273
#                     },
#                     "southwest": {
#                         "lat": 17.48123757010728,
#                         "lng": 97.09642427010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "46b3712deba416ffb6bd73d47706eed2a32f704a",
#             "name": "Yoe Yoe Lay",
#             "photos": [
#                 {
#                     "height": 1600,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115898981197507566837\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAWP7YssSPtJssvUyX9Lk3oxOro7clSubrHUUi6a7GMCIdpAK4y3M6mvHR-bs703aCS14s0OlJZ0WnMTJKvQopQGxe43lMe8Ggq0EU_RPYQ0wwmZSM-o9wlZUmRWtcwQcdEhDfI6n29zkzJTi9p96nlFc4GhTCF5L0ZhK2mU5OWJL1IkOSCtK6_g",
#                     "width": 2400
#                 }
#             ],
#             "place_id": "ChIJNfe3UHcKwzARK2c12ReQLhE",
#             "plus_code": {
#                 "compound_code": "F3MX+23 Ka Dai Dutt, Myanmar (Burma)",
#                 "global_code": "7M9VF3MX+23"
#             },
#             "rating": 3.3,
#             "reference": "ChIJNfe3UHcKwzARK2c12ReQLhE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 44,
#             "vicinity": "Myanmar (Burma)"
#         }
#     ],
#     "status": "OK"
# }
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.156932,
#                     "lng": 37.2617452
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.15844132989272,
#                         "lng": 37.26479365
#                     },
#                     "southwest": {
#                         "lat": 25.15574167010728,
#                         "lng": 37.26072904999999
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "ff4dc7ee75f42932aee814fedee7eeb04724a5c0",
#             "name": "Royal Tours Permanent Camp",
#             "photos": [
#                 {
#                     "height": 1100,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100370208616219033014\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAM_pXYTj3slacgGmAg_Z0x_k93CL37X0Pw0yrZS3js0p28ytPHYBjPBZTPkRqwuFELO3CyaNB_Y7hme028aMZT9G1dbCWyCIlIB9JB_5wDAmw7DKG7qIB7V3bL3cqrZO3EhCEWWoDfqP1g6k9C11zH654GhQNualXT2q3qQVEx_VRWpU31y18XA",
#                     "width": 1242
#                 }
#             ],
#             "place_id": "ChIJX65Fb7yfsBURKtYzWDNOrek",
#             "plus_code": {
#                 "compound_code": "5746+QM Umluj Saudi Arabia",
#                 "global_code": "7GQV5746+QM"
#             },
#             "rating": 4.5,
#             "reference": "ChIJX65Fb7yfsBURKtYzWDNOrek",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "48334, Saudi Arabia"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.040592,
#                     "lng": 37.253971
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.04190087989272,
#                         "lng": 37.25534172989273
#                     },
#                     "southwest": {
#                         "lat": 25.03920122010727,
#                         "lng": 37.25264207010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "c13ed37d68ce493712b9ec59e3426448ca0f8f44",
#             "name": "\u0639\u0631\u0648\u0633 \u0627\u0644\u0634\u0627\u0637\u0626 \u0644\u0644\u0648\u062d\u062f\u0627\u062a \u0627\u0644\u0633\u0643\u0646\u064a\u0629 \u0627\u0644\u0645\u0641\u0631\u0648\u0634\u0629",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3120,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114994371548559210564\">Hana Cardova</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAhZFJuc5TGRbwr7xp428r5ATQmmNyzjFx677ssu8u-cF0bTUVjjHMDz29L36I9TpomHU0ECsHFtb4wMeYiVCe10oRWCRXF1RbFlsUs0xyj_-zxdI8Sqh70QAir__1hBFlEhDFFXud8GNSa800oHeGurZdGhSxu-i-yOQ7s-Xxeh1bAh4ISOf5bQ",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJw4k00-GmsBURCTZt9UVIOio",
#             "plus_code": {
#                 "compound_code": "27R3+6H Umluj Saudi Arabia",
#                 "global_code": "7GQV27R3+6H"
#             },
#             "rating": 3.2,
#             "reference": "ChIJw4k00-GmsBURCTZt9UVIOio",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 164,
#             "vicinity": "King Abdullah Road, Al Dawayhi\u060c Umluj"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.022764,
#                     "lng": 37.26586
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.02411362989272,
#                         "lng": 37.26720987989272
#                     },
#                     "southwest": {
#                         "lat": 25.02141397010728,
#                         "lng": 37.26451022010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "64f23c593365ab07f4067d36b1086c3dd9a90e62",
#             "name": "Juman Hotel",
#             "place_id": "ChIJZ7SMkAinsBURf1DnyJzqlOs",
#             "plus_code": {
#                 "compound_code": "27F8+48 Umluj Saudi Arabia",
#                 "global_code": "7GQV27F8+48"
#             },
#             "rating": 5,
#             "reference": "ChIJZ7SMkAinsBURf1DnyJzqlOs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "King Abdullah Rd, Umluj"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.0228048,
#                     "lng": 37.2659093
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.02412762989272,
#                         "lng": 37.26726717989272
#                     },
#                     "southwest": {
#                         "lat": 25.02142797010728,
#                         "lng": 37.26456752010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "191dfd6aff0d76c8d2882418b3ece9094d5d977b",
#             "name": "Shada Collection Mina Hotel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106410034747392052763\">ibrahim alsayed</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAuIUiINLCU1QwOmkJJJApVy7oWpSyW2PFkAAfaT6BlnRTqYpnC8JNQFEUqMeXpFUemc_iz1N98jYacSq8MamzHPEpVTN4LJN6j3IQIs3JhNhPT1ebaXK9KTtVKAzGqfX1EhDs1Stsl4VVBN8s7kLcMM3sGhSLkAOhcDqSMPnlTOpVZep-DhNdMQ",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJ2_hrmwinsBURF7uwgiIdB8w",
#             "plus_code": {
#                 "compound_code": "27F8+49 Umluj Saudi Arabia",
#                 "global_code": "7GQV27F8+49"
#             },
#             "rating": 3.9,
#             "reference": "ChIJ2_hrmwinsBURF7uwgiIdB8w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 158,
#             "vicinity": "King Abdullah Rd, Umluj"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.0325904,
#                     "lng": 37.2570057
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.03390552989272,
#                         "lng": 37.25838357989272
#                     },
#                     "southwest": {
#                         "lat": 25.03120587010728,
#                         "lng": 37.25568392010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "81b2265a909e4961aee5d32e7469c06aa45fd05c",
#             "name": "HP Red Sea Hotel",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110396888368178619339\">baligh moharm</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAFy04JULTYCUP1kNrv2hJC-umn-EeP19VeshVCRGoyXcuwA512D9wpXuzMuMl--EJH_6QFJmGqzzD41TGi7u68iNLrEyENVcKSo_RDNszjzQTdv0wx3upIvl6RbRU4apGEhDlnJo6YAWchWyypoTvKyX0GhQvCxYYyTy8HgzV4xoRDGmmXAyMbg",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJx3SqsbWnsBURV6IDPtyOs5s",
#             "plus_code": {
#                 "compound_code": "27M4+2R Umluj Saudi Arabia",
#                 "global_code": "7GQV27M4+2R"
#             },
#             "rating": 3.9,
#             "reference": "ChIJx3SqsbWnsBURV6IDPtyOs5s",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 123,
#             "vicinity": "\u0637\u0631\u064a\u0642 \u0627\u0644\u0645\u0644\u0643 \u0639\u0628\u062f\u0627\u0644\u0644\u0647\u060c\u060c Umluj"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 25.0876443,
#                     "lng": 37.2642195
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 25.08900417989272,
# ...
#                     ],
#                     "photo_reference": "CmRaAAAAUbW_bqr_HpB3tWMGcHmc1VHKEaqUyJ7d6nyrBtpkCwXlusyl8-MZj0X6yViU6iZHFf8w4ha6W1Fhkb6RtBd4pCtEAej2R1zCcu-P9WVMjb0i3oJ4k_uv9xhEiHW444BtEhBHIIaIfQzkAvtmB04j58FHGhS9saN-IST-s7LYJG0ExK52Ai-e9g",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJkUPYo8-c4pQR8cqIGjYL1M8",
#             "plus_code": {
#                 "compound_code": "GRX2+R9 Marau, State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839GRX2+R9"
#             },
#             "rating": 4.5,
#             "reference": "ChIJkUPYo8-c4pQR8cqIGjYL1M8",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 93,
#             "vicinity": "Av. Julio Borella, 1010 - Centro, Marau"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.2611162,
#                     "lng": -52.4129643
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.25979262010728,
#                         "lng": -52.41167077010728
#                     },
#                     "southwest": {
#                         "lat": -28.26249227989272,
#                         "lng": -52.41437042989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "edc061ed91f50df806b71f594835b7c833e07a09",
#             "name": "Hotel S\u00e3o Vicente",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3804,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102354926501496525708\">Hotel S\u00e3o Vicente</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAdNzuD03jQOBI9PtGHDGcNfME0p_DkpsjTZJblaMP41AUKwJkzL3WfPWEOc4DXhKageMa6gMRMQmwY_uO8Gf2_0T2qynPAh-6_PxcknN9aCziRjQYu3FvjfPCoKgqhySMEhCvR5TlrcbCF-CXr_cgRdTKGhRkMsg2yg90H_647VIAAV7j_poPLA",
#                     "width": 5706
#                 }
#             ],
#             "place_id": "ChIJnXEtl4LA4pQR9il9mSh_Vrs",
#             "plus_code": {
#                 "compound_code": "PHQP+HR Centro, Passo Fundo - State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839PHQP+HR"
#             },
#             "rating": 4,
#             "reference": "ChIJnXEtl4LA4pQR9il9mSh_Vrs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 437,
#             "vicinity": "R. Teixeira Soares, 962 - Centro, Passo Fundo"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.2634053,
#                     "lng": -52.405171
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.26209142010728,
#                         "lng": -52.40390212010728
#                     },
#                     "southwest": {
#                         "lat": -28.26479107989272,
#                         "lng": -52.40660177989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6c0dd3e74f56b7f8f4d26157827ff0a02e78515b",
#             "name": "Bento Hotel",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114188502732382146246\">A Google User</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA1a8XrxQlOnIz0J30S1r4EkI9u9no9roQR4NBTArZ2QQU_1WTLCixch33Jgk20IwmmMeDSombhLtMub5NRofZSj8qY80i3_D9bL02cCrujBH0lJzm0aXqRP6eUxfL78f1EhCIIxvWe490QyB_Wagyqs_OGhSuymFA2YTj4VWb-WkGQovH1D1ttg",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJ2eWDQH-_4pQRneV6KTJ0A-w",
#             "plus_code": {
#                 "compound_code": "PHPV+JW Centro, Passo Fundo - State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839PHPV+JW"
#             },
#             "rating": 3.6,
#             "reference": "ChIJ2eWDQH-_4pQRneV6KTJ0A-w",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 146,
#             "vicinity": "Rua Bento Gon\u00e7alves, 219 B - Centro, Passo Fundo"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.2421466,
#                     "lng": -52.373056
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.24083987010728,
#                         "lng": -52.37171467010727
#                     },
#                     "southwest": {
#                         "lat": -28.24353952989272,
#                         "lng": -52.37441432989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "6c00702526a22ba62f657573f63d396062c0695c",
#             "name": "Hotel Mata Nativa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104204425028203132713\">Marcelo Centenaro</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAAPWhhiX_VzHItLTbpDeO2bSL_X1AeBSKx5BycgEFd85RHliGMJbSRlHllJCMwu41lw4_pQylQKMpLoeJc5Fgda0gbPEpjTooWh0ct0wvqdaI6zfiue29OfPIS_VSQFbqEhAVcja32mzz4zXYF90lrPi1GhTuIca1RglE3dolh2RGLg3yKql_lQ",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJ-TZJsgXA4pQRAyqBx3IWLzQ",
#             "plus_code": {
#                 "compound_code": "QJ5G+4Q Lot. Parque Farroupilha, Passo Fundo - State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839QJ5G+4Q"
#             },
#             "rating": 4.5,
#             "reference": "ChIJ-TZJsgXA4pQRAyqBx3IWLzQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 262,
#             "vicinity": "R. Tramanda\u00ed, 86 - Lot. Parque Farroupilha, Passo Fundo"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.83795899999999,
#                     "lng": -51.8925028
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.83669072010728,
#                         "lng": -51.89113127010727
#                     },
#                     "southwest": {
#                         "lat": -28.83939037989272,
#                         "lng": -51.89383092989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1815d83521cda26d6c0b5cc3c552a45e566ab4a0",
#             "name": "Recanto S\u00e3o Carlos",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116171535912282713723\">antonio geraldo dalla costa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAJ71JgCpmsO80XRL7Fi07dawk0scfXWwjbFMu9oUt7RZ0NMaJdg04TKhvdhetShO2VZm5CkIiRgrvJZO3l1A8m0tq3dyxQst9Gu1sOtpXjYTlVUKJkaO8oTkqCPWSmUzKEhCij5SiVxoRMswNAXFj769vGhQMmu3BZfVS_XZ8-viP014mXchMOA",
#                     "width": 5312
#                 }
#             ],
#             "place_id": "ChIJ8zS1hPekHZURermcMlw_IMY",
#             "plus_code": {
#                 "compound_code": "5464+RX Imac. Concei\u00e7\u00e3o, Guapor\u00e9 - State of Rio Grande do Sul, Brazil",
#                 "global_code": "583C5464+RX"
#             },
#             "rating": 4.6,
#             "reference": "ChIJ8zS1hPekHZURermcMlw_IMY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 151,
#             "vicinity": "Av. Scalabrini, 40 - Imac. Concei\u00e7\u00e3o, Guapor\u00e9"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.4586163,
#                     "lng": -52.2000468
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.45727087010728,
#                         "lng": -52.19883907010728
#                     },
#                     "southwest": {
#                         "lat": -28.45997052989272,
#                         "lng": -52.20153872989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "42439d71b7038e4fba390c5f8c6a41e5e812e7d1",
#             "name": "HOTEL BELL STTAR CENTRO",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1920,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109950997610876311596\">Jo\u00e3o Ambr\u00f3sio</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9GI8QhZTQXV_XUIPf7WFieKdU9g2kCV0IODRZvV6xvw1gEM4hmXrWzwlwebJQzPtNKCFYb8K8xLs6KJ41Llo8DXJtR7HAGv4ro5R_BIwZtHy6se2Qlm4LXgk-9AMwvoOEhCpp_9yw9wcvtOWWbT1pMtEGhQnTZE8MjjBuv6snyb3_G0cvGRm6A",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJqRyiPc-c4pQRbRAPUU0bSO4",
#             "plus_code": {
#                 "compound_code": "GQRX+HX Vila Angela Borella, Marau - State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839GQRX+HX"
#             },
#             "rating": 4,
#             "reference": "ChIJqRyiPc-c4pQRbRAPUU0bSO4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 116,
#             "vicinity": "1627-1801, Av. Bar\u00e3o do Rio Branco - Vila Angela Borella, Marau"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.4207873,
#                     "lng": -52.2155418
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.41956977010728,
#                         "lng": -52.21443392010728
#                     },
#                     "southwest": {
#                         "lat": -28.42226942989272,
#                         "lng": -52.21713357989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "0fbdb7e0d67be8a033cf3af2ff1b7812aa39350f",
#             "name": "Hotel Bell Sttar",
#             "photos": [
#                 {
#                     "height": 2530,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113472336205974780743\">Rafael Sebastiani</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA0GZrtHSX49Arq0EZgjnQ7z7Vm0qzOwdD2uAVQ6AFFHsUaU4AWUab4Pg3LjpumZj3lIzLNcKTrJxF0eCgghHfpFrzGsO7svU1_YpRHBebQ_0lfi5kbdudf37Rr0mP-YsOEhAHiaQj_PIrKcWVeyu-82XXGhT80X2qUoSpF5ePysfxFJ1oARgJLg",
#                     "width": 4380
#                 }
#             ],
#             "place_id": "ChIJ-ZBCrmub4pQRQ4kEhax--b4",
#             "plus_code": {
#                 "compound_code": "HQHM+MQ Marau, State of Rio Grande do Sul, Brazil",
#                 "global_code": "5839HQHM+MQ"
#             },
#             "rating": 4.3,
#             "reference": "ChIJ-ZBCrmub4pQRQ4kEhax--b4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 267,
#             "vicinity": "Rodovia RS-324, Km 86, R. Jos\u00e9 Posser Sobrinho, N\u00b0 846, Marau"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": -28.832493,
#                     "lng": -52.510825
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -28.83113697010728,
#                         "lng": -52.50954357010728
#                     },
#                     "southwest": {
#                         "lat": -28.83383662989272,
#                         "lng": -52.51224322989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1b2a8fd327fdc86c955238670116cf3b05ce1357",
#             "name": "Villablanca Hotel",
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117030449834008006849\">Olivar Correa</a>"
#                     ],
#                     "photo_reference": "CmRaAAAATIA6RK9fWJtBlFsKx0GuMHG0pbEpjM_CyXQ1jSYY5Hh_oUBsd1ZalQpJq_prUtqvz9nCcXBGHQRZGm8Fd3Ytwtngawx1mXXkA49wDaQnbKpcIJDWx4aJo1tixdZNQZYQEhDbVdL4B522gwsW9TTlsvcuGhRWRq2B-zq7v2KaAQKAOIv3FDvBHA",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJkwBVtKJFHZURP7RCQErxhdM",
#             "plus_code": {
#                 "compound_code": "5F9Q+2M Centro, Soledade - State of Rio Grande do Sul, Brazil",
#                 "global_code": "58395F9Q+2M"
#             },
#             "rating": 3.7,
#             "reference": "ChIJkwBVtKJFHZURP7RCQErxhdM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 147,
#             "vicinity": "Av. Maur\u00edcio Cardoso, 639 - Centro, Soledade"
#         }
#     ],
#     "status": "OK"
# }
#    City ID      City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       92   Kyaikto           0      MM  1584987841        60  17.30   97.02
# 1       99     Umluj           0      SA  1584987842        27  25.02   37.27
# 2      157  Bac Lieu           0      VN  1584987576        87   9.29  105.72
# 3      160    Castro           0      BR  1584987847        34 -24.79  -50.01
# 4      193   Kalawit           0      PH  1584987849        87   8.07  122.52
# 5      221  Buraidah           0      SA  1584987851        15  26.33   43.98
# 6      457     Marau           0      BR  1584987866        34 -28.45  -52.20
#
#    Max Temp  Wind Speed                             Hotel Name
# 0     70.99        2.91                       The Merit Resort
# 1     70.99        3.42             Royal Tours Permanent Camp
# 2     75.49        4.03                            Hotel Royal
# 3     77.29        3.13  Bourbon Ponta Grossa Convention Hotel
# 4     74.23        4.81      Top Mars Imanuel Hotel And Resort
# 5     62.60        2.24                 Mövenpick Hotel Qassim
# 6     86.83        1.63                 PRIX HOTEL Passo Fundo

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Marker added to mark hotels
markers = gmaps.marker_layer(locations,
    info_box_content=[f"Hotel loc: {rate}" for rate in hotel_info])

fig.add_layer(markers)

# Display Map
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
