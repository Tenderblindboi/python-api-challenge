# %%
from scipy.stats import linregress
from pprint import pprint 
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from config import weather_api_key
from citipy import citipy

lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# Create list that will hold latitudes and longitudes
lat_lngs = []

# Create list that will hold, city names
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# For loop will identify the nearest city for each latitude and longitude
# with citipy

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # append unique city names to city list
    if city not in cities:
        cities.append(city)

# %%
# Print number of cities
lat_lngs_list = list(lat_lngs)
print(len(cities))
# Out:
# 603

# %%
# Url From openweather for API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&"

# Lists for storing values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

# %%
# Loop through cities making the API call
i = 1
for city in cities:
    city=city
    query_url = url + "appid=" + weather_api_key + "&q=" + city
    response = requests.get(query_url).json()
    
    # extracting data and cleaning data
# print cleaned data
    try:
        
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City name not found.")
# Out:
# Processing record 1|bredasdorp
# Processing record 2|yermakovskoye
# Processing record 3|punta arenas
# Processing record 4|senftenberg
# Processing record 5|rocha
# Processing record 6|chokurdakh
# Processing record 7|salalah
# City name not found.
# City name not found.
# Processing record 8|jamestown
# Processing record 9|khatanga
# Processing record 10|berdigestyakh
# Processing record 11|kaitangata
# Processing record 12|mataura
# City name not found.
# City name not found.
# Processing record 13|codrington
# Processing record 14|albany
# Processing record 15|hermanus
# Processing record 16|port elizabeth
# Processing record 17|innisfail
# Processing record 18|atuona
# Processing record 19|talnakh
# Processing record 20|sumkino
# Processing record 21|hobart
# Processing record 22|korem
# Processing record 23|emet
# Processing record 24|busselton
# Processing record 25|kapaa
# City name not found.
# Processing record 26|longyearbyen
# Processing record 27|mahebourg
# Processing record 28|burnie
# Processing record 29|butaritari
# Processing record 30|kavieng
# Processing record 31|vaini
# Processing record 32|georgetown
# Processing record 33|ushuaia
# Processing record 34|puerto ayora
# Processing record 35|port alfred
# Processing record 36|imeni poliny osipenko
# Processing record 37|ribeira grande
# Processing record 38|te anau
# Processing record 39|bluff
# Processing record 40|yellowknife
# Processing record 41|qaanaaq
# Processing record 42|nikolskoye
# Processing record 43|barra do garcas
# Processing record 44|pucallpa
# Processing record 45|tasiilaq
# Processing record 46|meulaboh
# City name not found.
# Processing record 47|marand
# Processing record 48|hofn
# Processing record 49|luderitz
# Processing record 50|belyy yar
# Processing record 51|houma
# Processing record 52|east london
# Processing record 53|haines junction
# Processing record 54|gizo
# City name not found.
# Processing record 55|thompson
# Processing record 56|faanui
# Processing record 57|san patricio
# Processing record 58|barrow
# Processing record 59|vila franca do campo
# Processing record 60|dikson
# Processing record 61|port hardy
# Processing record 62|nanortalik
# Processing record 63|taoudenni
# Processing record 64|portobelo
# Processing record 65|torbay
# Processing record 66|cape town
# Processing record 67|mount gambier
# City name not found.
# Processing record 68|rikitea
# Processing record 69|vila velha
# Processing record 70|svetlaya
# Processing record 71|la vergne
# Processing record 72|rongcheng
# Processing record 73|airai
# Processing record 74|saint-philippe
# Processing record 75|russell
# Processing record 76|calama
# Processing record 77|bubaque
# Processing record 78|solnechnyy
# Processing record 79|fortuna
# Processing record 80|lata
# Processing record 81|vadso
# Processing record 82|marzuq
# Processing record 83|bilibino
# Processing record 84|geraldton
# Processing record 85|lebu
# Processing record 86|taseyevo
# City name not found.
# City name not found.
# Processing record 87|shingu
# Processing record 88|kimberley
# Processing record 89|half moon bay
# Processing record 90|garissa
# Processing record 91|blagoyevo
# Processing record 92|pevek
# Processing record 93|kyaikto
# Processing record 94|tsaratanana
# Processing record 95|tuatapere
# Processing record 96|cockburn town
# Processing record 97|fukue
# Processing record 98|emden
# Processing record 99|sao filipe
# Processing record 100|umm lajj
# Processing record 101|chuy
# Processing record 102|miandrivazo
# Processing record 103|saint anthony
# Processing record 104|seoul
# Processing record 105|hilo
# Processing record 106|port blair
# Processing record 107|bambous virieux
# Processing record 108|exu
# Processing record 109|touros
# Processing record 110|oss
# Processing record 111|shimoda
# Processing record 112|oistins
# City name not found.
# City name not found.
# City name not found.
# Processing record 113|ostrovnoy
# Processing record 114|khani
# City name not found.
# City name not found.
# Processing record 115|pacific grove
# Processing record 116|isangel
# Processing record 117|januaria
# Processing record 118|quirinopolis
# Processing record 119|carnarvon
# Processing record 120|anadyr
# City name not found.
# Processing record 121|keti bandar
# Processing record 122|alice springs
# Processing record 123|kruisfontein
# Processing record 124|traverse city
# City name not found.
# Processing record 125|ninghai
# Processing record 126|guerrero negro
# Processing record 127|tiksi
# Processing record 128|mykolayiv
# Processing record 129|thinadhoo
# Processing record 130|lac du bonnet
# Processing record 131|tautira
# City name not found.
# Processing record 132|penablanca
# Processing record 133|los llanos de aridane
# Processing record 134|yar-sale
# Processing record 135|pangnirtung
# Processing record 136|dekar
# Processing record 137|virginia beach
# City name not found.
# Processing record 138|norman wells
# Processing record 139|nara
# Processing record 140|hoi an
# Processing record 141|upernavik
# Processing record 142|baracoa
# Processing record 143|ponta do sol
# City name not found.
# Processing record 144|avarua
# Processing record 145|provideniya
# Processing record 146|marinette
# Processing record 147|leningradskiy
# Processing record 148|cayenne
# Processing record 149|bozeman
# Processing record 150|eyl
# Processing record 151|dwarka
# Processing record 152|malureni
# Processing record 153|san cristobal
# Processing record 154|constitucion
# Processing record 155|cidreira
# Processing record 156|olafsvik
# Processing record 157|dudinka
# Processing record 158|bac lieu
# Processing record 159|saldanha
# Processing record 160|svetlogorsk
# Processing record 161|castro
# Processing record 162|lavrentiya
# Processing record 163|vaitape
# Processing record 164|north bend
# Processing record 165|coihaique
# Processing record 166|lompoc
# Processing record 167|turayf
# Processing record 168|pemangkat
# Processing record 169|sao joao da barra
# Processing record 170|vanimo
# Processing record 171|del rio
# Processing record 172|launceston
# Processing record 173|mahibadhoo
# Processing record 174|aykhal
# Processing record 175|martapura
# Processing record 176|mirabad
# Processing record 177|new norfolk
# Processing record 178|lukhovitsy
# Processing record 179|la macarena
# Processing record 180|dulce nombre de culmi
# Processing record 181|walvis bay
# Processing record 182|bonavista
# Processing record 183|matara
# Processing record 184|puerto baquerizo moreno
# Processing record 185|sambava
# City name not found.
# Processing record 186|lincoln
# Processing record 187|najran
# Processing record 188|kloulklubed
# Processing record 189|blackwater
# Processing record 190|laguna
# Processing record 191|burnham
# Processing record 192|samarai
# Processing record 193|souillac
# Processing record 194|kalawit
# Processing record 195|kenai
# Processing record 196|ust-nera
# Processing record 197|ugoofaaru
# Processing record 198|arequipa
# Processing record 199|ixtapa
# Processing record 200|biloli
# Processing record 201|gaoyou
# Processing record 202|avera
# Processing record 203|cabo san lucas
# Processing record 204|tuktoyaktuk
# Processing record 205|kralendijk
# City name not found.
# Processing record 206|moron
# Processing record 207|saskylakh
# Processing record 208|the valley
# Processing record 209|mbini
# Processing record 210|nome
# Processing record 211|iqaluit
# Processing record 212|tanete
# Processing record 213|paamiut
# Processing record 214|pangkalanbuun
# Processing record 215|vega de alatorre
# Processing record 216|bathsheba
# Processing record 217|tabou
# Processing record 218|birao
# Processing record 219|severo-kurilsk
# Processing record 220|adre
# Processing record 221|bowmore
# Processing record 222|buraydah
# Processing record 223|buchanan
# Processing record 224|baturaja
# Processing record 225|presidencia roque saenz pena
# Processing record 226|mount isa
# Processing record 227|coquimbo
# Processing record 228|jimenez
# Processing record 229|havelock
# Processing record 230|iquitos
# Processing record 231|providencia
# Processing record 232|lorengau
# Processing record 233|kenora
# Processing record 234|tura
# Processing record 235|tiruchchirappalli
# Processing record 236|orda
# Processing record 237|ketchikan
# City name not found.
# Processing record 238|kodiak
# Processing record 239|san ramon
# Processing record 240|ust-kulom
# Processing record 241|chambery
# City name not found.
# Processing record 242|casper
# Processing record 243|raudeberg
# Processing record 244|saint-augustin
# Processing record 245|zhigansk
# Processing record 246|iskateley
# Processing record 247|lerwick
# Processing record 248|katherine
# Processing record 249|ruteng
# Processing record 250|virden
# Processing record 251|pisco
# Processing record 252|chino valley
# Processing record 253|sapa
# Processing record 254|doha
# Processing record 255|jalu
# Processing record 256|sakakah
# Processing record 257|bethel
# Processing record 258|saint george
# Processing record 259|sayat
# Processing record 260|elat
# Processing record 261|lubango
# Processing record 262|grand gaube
# Processing record 263|progreso
# Processing record 264|kununurra
# Processing record 265|deputatskiy
# Processing record 266|srednekolymsk
# Processing record 267|la ronge
# Processing record 268|krasnoselkup
# Processing record 269|santa maria visitacion
# Processing record 270|tomatlan
# Processing record 271|golakganj
# Processing record 272|dunedin
# Processing record 273|waipawa
# Processing record 274|ginda
# Processing record 275|pakokku
# Processing record 276|vikhorevka
# Processing record 277|kyra
# City name not found.
# Processing record 278|komsomolskiy
# Processing record 279|korla
# Processing record 280|le port
# Processing record 281|antofagasta
# Processing record 282|miami
# Processing record 283|gimli
# Processing record 284|honiara
# Processing record 285|cerrito
# Processing record 286|champerico
# Processing record 287|bure
# Processing record 288|contamana
# Processing record 289|alvorada
# Processing record 290|pyaozerskiy
# Processing record 291|lawrenceburg
# Processing record 292|mujiayingzi
# Processing record 293|troitskoye
# Processing record 294|xuchang
# Processing record 295|linxia
# Processing record 296|carutapera
# Processing record 297|wad rawah
# Processing record 298|batticaloa
# Processing record 299|tilichiki
# Processing record 300|pestovo
# Processing record 301|klaksvik
# Processing record 302|andreapol
# City name not found.
# Processing record 303|hambantota
# Processing record 304|salinopolis
# Processing record 305|sola
# Processing record 306|aldan
# Processing record 307|luganville
# Processing record 308|waingapu
# Processing record 309|cherskiy
# Processing record 310|kahului
# Processing record 311|jesup
# Processing record 312|arraial do cabo
# Processing record 313|adrar
# Processing record 314|rawlins
# Processing record 315|maumere
# Processing record 316|kem
# City name not found.
# Processing record 317|west monroe
# Processing record 318|patur
# Processing record 319|nur
# Processing record 320|vadakku valliyur
# City name not found.
# Processing record 321|farah
# Processing record 322|lilongwe
# Processing record 323|sabang
# Processing record 324|george
# Processing record 325|karasburg
# Processing record 326|wainwright
# Processing record 327|iralaya
# Processing record 328|urubicha
# Processing record 329|huanren
# Processing record 330|susaki
# Processing record 331|karratha
# Processing record 332|mareeba
# Processing record 333|ilulissat
# Processing record 334|hami
# Processing record 335|isetskoye
# City name not found.
# City name not found.
# Processing record 336|hamilton
# Processing record 337|vardo
# Processing record 338|songjianghe
# Processing record 339|pahrump
# Processing record 340|bourail
# Processing record 341|caravelas
# Processing record 342|minna
# Processing record 343|alexandria
# Processing record 344|krasnoturansk
# Processing record 345|comodoro rivadavia
# Processing record 346|ancud
# Processing record 347|arman
# Processing record 348|ouro preto do oeste
# Processing record 349|lira
# Processing record 350|northam
# Processing record 351|srivardhan
# Processing record 352|mirnyy
# Processing record 353|bengkulu
# Processing record 354|mezen
# Processing record 355|chapais
# Processing record 356|chaman
# Processing record 357|tahe
# Processing record 358|syracuse
# Processing record 359|saint-georges
# Processing record 360|sibolga
# Processing record 361|conceicao das alagoas
# Processing record 362|spassk
# Processing record 363|yeniseysk
# Processing record 364|mayo
# Processing record 365|slave lake
# Processing record 366|hithadhoo
# Processing record 367|mitu
# Processing record 368|sept-iles
# Processing record 369|zaltan
# Processing record 370|qeshm
# Processing record 371|jumla
# Processing record 372|inuvik
# Processing record 373|boa vista
# Processing record 374|manokwari
# Processing record 375|sault sainte marie
# Processing record 376|sao joao do piaui
# Processing record 377|coahuayana
# Processing record 378|sioux lookout
# Processing record 379|balaipungut
# Processing record 380|veraval
# Processing record 381|bardiyah
# City name not found.
# Processing record 382|vila
# Processing record 383|magadan
# Processing record 384|praia
# Processing record 385|cabedelo
# City name not found.
# Processing record 386|havoysund
# Processing record 387|gat
# Processing record 388|mar del plata
# Processing record 389|kamenka
# Processing record 390|zastron
# Processing record 391|vao
# Processing record 392|baft
# Processing record 393|golden
# Processing record 394|muros
# Processing record 395|jacareacanga
# Processing record 396|skibbereen
# Processing record 397|nogliki
# Processing record 398|pochutla
# Processing record 399|berlevag
# Processing record 400|quatre cocos
# Processing record 401|nouakchott
# Processing record 402|hervey bay
# City name not found.
# Processing record 403|along
# Processing record 404|erpeli
# Processing record 405|nargana
# Processing record 406|todos santos
# Processing record 407|itoman
# Processing record 408|sharan
# Processing record 409|monrovia
# Processing record 410|bati
# City name not found.
# Processing record 411|san carlos de bariloche
# Processing record 412|xining
# Processing record 413|esperance
# Processing record 414|dunhua
# Processing record 415|kutum
# Processing record 416|la plata
# Processing record 417|bilma
# Processing record 418|victoria
# Processing record 419|sitka
# Processing record 420|puerto montt
# Processing record 421|panama city
# Processing record 422|namatanai
# Processing record 423|marawi
# Processing record 424|qianguo
# Processing record 425|dembi dolo
# Processing record 426|seymchan
# Processing record 427|bonfim
# Processing record 428|yining
# Processing record 429|ostersund
# Processing record 430|hovd
# Processing record 431|agadir
# Processing record 432|aklavik
# Processing record 433|warrington
# City name not found.
# Processing record 434|thunder bay
# Processing record 435|alofi
# Processing record 436|cuamba
# Processing record 437|talara
# Processing record 438|passo de camaragibe
# City name not found.
# Processing record 439|kantunilkin
# Processing record 440|sur
# Processing record 441|lookan
# Processing record 442|falmouth
# City name not found.
# Processing record 443|hualmay
# Processing record 444|badvel
# Processing record 445|suez
# Processing record 446|alekseyevka
# Processing record 447|zenzeli
# Processing record 448|eyemouth
# Processing record 449|karaton
# Processing record 450|fontanka
# Processing record 451|putnok
# Processing record 452|zheleznodorozhnyy
# Processing record 453|batagay-alyta
# Processing record 454|rawson
# Processing record 455|bonthe
# Processing record 456|pontiac
# City name not found.
# Processing record 457|teguise
# Processing record 458|marau
# Processing record 459|ternate
# Processing record 460|kashi
# Processing record 461|bodden town
# City name not found.
# Processing record 462|mpongwe
# Processing record 463|sal rei
# Processing record 464|otradnoye
# Processing record 465|tayoltita
# Processing record 466|bako
# City name not found.
# Processing record 467|kalmunai
# Processing record 468|port keats
# Processing record 469|strezhevoy
# Processing record 470|katsuura
# Processing record 471|tanout
# Processing record 472|shizunai
# Processing record 473|santa isabel do rio negro
# Processing record 474|beidao
# Processing record 475|morehead
# Processing record 476|yerbogachen
# Processing record 477|tahta
# Processing record 478|margate
# Processing record 479|praia da vitoria
# Processing record 480|sao raimundo nonato
# Processing record 481|melfort
# Processing record 482|lagoa
# Processing record 483|kholm
# Processing record 484|laramie
# Processing record 485|narsaq
# Processing record 486|itarsi
# Processing record 487|sisimiut
# Processing record 488|benguela
# Processing record 489|chara
# Processing record 490|tagusao
# Processing record 491|ranong
# Processing record 492|ishigaki
# Processing record 493|staszow
# Processing record 494|vostok
# Processing record 495|mbouda
# Processing record 496|daru
# Processing record 497|la baule-escoublac
# Processing record 498|hasaki
# City name not found.
# Processing record 499|gigmoto
# Processing record 500|shelburne
# Processing record 501|wichita falls
# Processing record 502|dingle
# Processing record 503|olinda
# Processing record 504|sanmenxia
# Processing record 505|farsund
# City name not found.
# Processing record 506|jaciara
# Processing record 507|somerset west
# Processing record 508|derzhavinsk
# Processing record 509|north platte
# Processing record 510|ewa beach
# Processing record 511|dongsheng
# Processing record 512|azanka
# Processing record 513|oranjemund
# Processing record 514|zubtsov
# Processing record 515|aksehir
# Processing record 516|chenzhou
# Processing record 517|bowen
# Processing record 518|wakkanai
# Processing record 519|sampit
# Processing record 520|dinar
# Processing record 521|cururupu
# Processing record 522|grindavik
# Processing record 523|gondanglegi
# Processing record 524|nushki
# Processing record 525|takaungu
# Processing record 526|portland
# Processing record 527|henties bay
# Processing record 528|kandri
# Processing record 529|naron
# Processing record 530|port-cartier
# Processing record 531|okato
# Processing record 532|san luis
# Processing record 533|kudeyevskiy
# Processing record 534|parede
# Processing record 535|puerto maldonado
# Processing record 536|mortka
# Processing record 537|presidente medici
# Processing record 538|padang
# Processing record 539|san lorenzo
# Processing record 540|husavik
# Processing record 541|batouri
# Processing record 542|beringovskiy
# Processing record 543|noumea
# Processing record 544|austin
# Processing record 545|rio claro
# Processing record 546|dalvik
# City name not found.
# Processing record 547|arlit
# Processing record 548|chicama
# Processing record 549|shubarshi
# Processing record 550|hirara
# Processing record 551|vangaindrano
# Processing record 552|rioja
# Processing record 553|seddon
# Processing record 554|price
# City name not found.
# Processing record 555|alamosa
# Processing record 556|tual
# Processing record 557|florida
# Processing record 558|nemuro
# Processing record 559|agadez

# %%
#Convert all the data extracted into a data frame
city_df = pd.DataFrame({"City":city_name, 
                        "Cloudiness":cloudiness, 
                        "Country":country, 
                        "Date":date, 
                        "Humidity":humidity,
                        "Lat":lat,
                        "Lng":lng,
                        "Max Temp":max_temp,
                        "Wind Speed":wind_speed
                                         })
city_df = city_df.rename_axis('City ID')

# %%
#Exporting data to csv file (will be used for vacation challenge as well)
city_df.to_csv("city_list.csv")

#Display DF
city_df.head()
# Out:
#                   City  Cloudiness Country        Date  Humidity    Lat  \
# City ID
# 0           Bredasdorp          93      ZA  1584987834        77 -34.53
# 1        Yermakovskoye         100      RU  1584987834        84  53.28
# 2         Punta Arenas         100      CL  1584987803        77 -53.15
# 3          Senftenberg           0      DE  1584987835        40  51.52
# 4                Rocha           0      UY  1584987835        38 -34.48
#
#            Lng  Max Temp  Wind Speed
# City ID
# 0        20.04     64.99        2.24
# 1        92.40     15.55        8.77
# 2       -70.92     62.01       20.80
# 3        14.02     37.40        6.93
# 4       -54.33     83.05        9.15

# %%
# data
#Converting Date and time 
timestamp = city_df["Date"][0]
converted_timestamp = datetime.utcfromtimestamp(timestamp)
shortened_timestamp = datetime.date(converted_timestamp)

#Creating 1st plot ( Latitude vs Max temp)
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature({shortened_timestamp})")
plt.savefig("Lat_vs_temp_plot")
plt.show()

# %% [markdown]
# ### 1st plot shows that the closer a city is to 0 Latitued (The equator) the warmer the weather temperature.

# %%
# 2nd plot ( humidity vs latitude)
plt.scatter(city_df["Lat"], city_df["Humidity"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.ylim(0, city_df["Humidity"].max()+50)
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title(f"City Latitude vs. Humidity ({shortened_timestamp})")
plt.savefig("Lat_vs_humidity_plot")
plt.show()

# %% [markdown]
# ### 2nd plot does not clearly shows any relation between humidity and latitude.

# %%
plt.scatter(city_df["Lat"], city_df["Cloudiness"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title(f"City Latitude vs. Cloudiness ({shortened_timestamp})")
plt.savefig("Lat_vs_cloudiness_plot")
plt.show()

# %% [markdown]
# ### 3rd plot does not clearly shows any relation between cloudiness and latitude

# %%
plt.scatter(city_df["Lat"], city_df["Wind Speed"], marker = "o", color = "blue",edgecolor = "black")
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.title(f"City Latitude vs. Wind Speed ({shortened_timestamp})")
plt.savefig("Lat_vs_windSpeed_plot")
plt.show()

# %% [markdown]
# ### 4th plot shows that most higher wind speeds happen in the southern and northern hemisphere areas known for hurricanes.
